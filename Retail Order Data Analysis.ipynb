# %%
import pandas as pd

# %%
df = pd.read_csv("C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv")

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df = df.rename(columns={'Order Id': 'Order_Id'})
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df = df.rename(columns={'Order Date': 'Order_Date'})
df = df.rename(columns={'Product Id': 'Product_Id'})
df = df.rename(columns={'cost price': 'Cost_Price'})
df = df.rename(columns={'Ship Mode': 'Ship_Mode'})
df = df.rename(columns={'List Price': 'List_Price'})
df = df.rename(columns={'Discount Percent': 'Discount_Percent'})
df = df.rename(columns={'Postal Code': 'Postal_Code'})
df = df.rename(columns={'Sub Category': 'Sub_Category'})
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
duplicate_df = df[df.duplicated()]
duplicate_df
# Out:
# Empty DataFrame
# Columns: [Order_Id, Order_Date, Ship_Mode, Segment, Country, City, State, Postal_Code, Region, Category, Sub_Category, Product_Id, Cost_Price, List_Price, Quantity, Discount_Percent, Discount, Sale_Price, Profit]
# Index: []

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df1 = df.isnull().sum()
df1
# Out:
# Order_Id            0
# Order_Date          0
# Ship_Mode           0
# Segment             0
# Country             0
# City                0
# State               0
# Postal_Code         0
# Region              0
# Category            0
# Sub_Category        0
# Product_Id          0
# Cost_Price          0
# List_Price          0
# Quantity            0
# Discount_Percent    0
# Discount            0
# Sale_Price          0
# Profit              0
# dtype: int64

# %%
df.fillna(0, inplace=True)
df
# Out:
#       Order_Id        Order_Date       Ship_Mode    Segment        Country  \
# 0            1     01 March 2023    Second Class   Consumer  United States
# 1            2    15 August 2023    Second Class   Consumer  United States
# 2            3   10 January 2023    Second Class  Corporate  United States
# 3            4      18 June 2022  Standard Class   Consumer  United States
# 4            5      13 July 2022  Standard Class   Consumer  United States
# ...        ...               ...             ...        ...            ...
# 9989      9990  18 February 2023    Second Class   Consumer  United States
# 9990      9991     17 March 2023  Standard Class   Consumer  United States
# 9991      9992    07 August 2022  Standard Class   Consumer  United States
# 9992      9993  19 November 2022  Standard Class   Consumer  United States
# 9993      9994      17 July 2022    Second Class   Consumer  United States
#
# ...

# %%
df.to_csv('C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv', index=False)

# %%
df['Country'] = df['Country'].str.strip()
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#creating a new column called discount
df["Discount"] = df['List_Price'] * df['Discount_Percent'] / 100
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
#creating a new column called Sale price
df['Sale_price'] = df["List_Price"] - df["Discount"]
df
df = df.rename(columns={'Sale_price' : 'Sale_Price'})
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df.to_csv('C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv', index=False)

# %%
# Check for duplicate indices
df[df.index.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_Id, Order_Date, Ship_Mode, Segment, Country, City, State, Postal_Code, Region, Category, Sub_Category, Product_Id, Cost_Price, List_Price, Quantity, Discount_Percent, Discount, Sale_Price, Profit, Sale_Price]
# Index: []

# %%
# Drop duplicate indices
df = df[~df.index.duplicated()]
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# Reset the index
df = df.reset_index(drop=True)
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df['Profit'] = df['Sale_Price'] - df['Cost_Price']
df

# %%
df.to_csv('C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv', index=False)

# %%
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
df = df.drop(columns=['Loss'])
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
import pandas as pd

# Assuming df is your DataFrame and 'column_name' is the column of interest
median_value = df[df['column_name'] != 0]['column_name'].median()
df['column_name'] = df['column_name'].replace(0, median_value)

print(df['column_name'])

# %%
# Finding columns with zero values
columns_with_zero = df.columns[(df == 0).any()].tolist()
print(columns_with_zero)
# Out:
# ['Cost_Price', 'List_Price', 'Discount', 'Sale_Price', 'Profit', 'Sale_Price']

# %%
#replacing the zeros by median imputaion
for column in ['Cost_Price', 'List_Price', 'Discount', 'Sale_Price', 'Profit']:
    df[column] = df[column].replace(0, df[column].median())
df
# Out:
#       Order_Id Order_Date       Ship_Mode    Segment        Country  \
# 0            1  01-Mar-23    Second Class   Consumer  United States
# 1            2  15-Aug-23    Second Class   Consumer  United States
# 2            3  10-Jan-23    Second Class  Corporate  United States
# 3            4  18-Jun-22  Standard Class   Consumer  United States
# 4            5  13-Jul-22  Standard Class   Consumer  United States
# ...        ...        ...             ...        ...            ...
# 9989      9990  18-Feb-23    Second Class   Consumer  United States
# 9990      9991  17-Mar-23  Standard Class   Consumer  United States
# 9991      9992  07-Aug-22  Standard Class   Consumer  United States
# 9992      9993  19-Nov-22  Standard Class   Consumer  United States
# 9993      9994  17-Jul-22    Second Class   Consumer  United States
#
#                  City       State  Postal_Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# ...

# %%
# Finding columns with zero values
columns_with_zero = df.columns[(df == 0).any()].tolist()
print(columns_with_zero)
# Out:
# []

# %%
df1 = df.isnull().sum()
df1
# Out:
# Order_Id            0
# Order_Date          0
# Ship_Mode           0
# Segment             0
# Country             0
# City                0
# State               0
# Postal_Code         0
# Region              0
# Category            0
# Sub_Category        0
# Product_Id          0
# Cost_Price          0
# List_Price          0
# Quantity            0
# Discount_Percent    0
# Discount            0
# Sale_Price          0
# Profit              0
# Sale_Price          0
# dtype: int64

# %%
df.to_csv('C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv', index=False)

# %%
# Creating a connection to the MySQL server

import pandas as pd
from sqlalchemy import create_engine

df = pd.read_csv('C://Users//Ananthram Vasu//Downloads//orders.csv//orders.csv')

username = 'root'      
password = '*Varsha123$'      
host = '127.0.0.1'              
port = '3306'              
database_name = 'Guvi_Project' 

connection_string = f'mysql+pymysql://{username}:{password}@{host}:{port}/{database_name}'
engine = create_engine(connection_string)
df.to_sql('Retail_orders', con=engine, if_exists='replace', index=False)

print("Data successfully uploaded to MySQL")
# Out:
# Data successfully uploaded to MySQL
# C:\Users\Ananthram Vasu\AppData\Local\Temp\ipykernel_25320\2492635001.py:18: UserWarning: The provided table name 'Retail_orders' is not found exactly as such in the database after writing the table, possibly due to case sensitivity issues. Consider using lower case table names.
#   df.to_sql('Retail_orders', con=engine, if_exists='replace', index=False)

# %%
import streamlit as st
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# Function to create a connection to the MySQL database
def create_db_connection(host, user, password, database_name):
    connection_string = f'mysql+pymysql://{user}:{password}@{host}/{database_name}'
    engine = create_engine(connection_string)
    return engine

# Streamlit app
st.title("Display Data from MySQL")

# Input fields for database connection details
host = st.text_input("Enter MySQL Host", "127.0.0.1")
user = st.text_input("Enter MySQL Username", "root")
password = st.text_input("Enter MySQL Password", type="password", value="*Varsha123$")
database_name = st.text_input("guvi_project")

# Query to execute
query = st.text_input("Enter SQL Query", "SELECT * FROM retail_orders LIMIT 10")

# Execute the query and display results
if st.button("Execute Query"):
    if host and user and password and database_name and query:
        try:
            engine = create_db_connection(host, user, password, database_name)
            df = pd.read_sql_query(query, con=engine)
            st.write("Query executed successfully!")
            st.dataframe(df)
        except Exception as e:
            st.error(f"An error occurred: {e}")
    else:
        st.warning("Please fill in all fields and provide a valid query.")
